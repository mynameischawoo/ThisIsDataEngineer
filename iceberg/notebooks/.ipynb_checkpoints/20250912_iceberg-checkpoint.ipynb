# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
        .appName("IcebergSparkWithMinIo") \
        .config("spark.sql.catalog.iceberg_catalog", "org.apache.iceberg.spark.SparkCatalog") \
        .config("spark.sql.catalog.iceberg_catalog.type", "rest") \
        .config("spark.sql.catalog.iceberg_catalog.uri", "http://iceberg-rest:8181") \
        .config("spark.sql.catalog.iceberg_catalog.warehouse", "s3://warehouse/") \
        .config("spark.sql.catalog.iceberg_catalog.io-impl", "org.apache.iceberg.aws.s3.S3FileIO") \
        .config("spark.sql.catalog.iceberg_catalog.s3.endpoint", "http://minio:9000") \
        .config("spark.sql.catalog.iceberg_catalog.s3.access-key-id", "admin") \
        .config("spark.sql.catalog.iceberg_catalog.s3.secret-access-key", "password") \
        .config("spark.sql.catalog.iceberg_catalog.s3.path-style-access", "true") \
        .getOrCreate()

spark.sql("SHOW CATALOGS").show()
# Out:
# +---------------+
# |        catalog|
# +---------------+
# |           demo|
# |iceberg_catalog|
# |  spark_catalog|
# +---------------+

# %%
spark.sql("SHOW DATABASES IN iceberg_catalog").show()
# Out:
# +---------+
# |namespace|
# +---------+
# |  default|
# +---------+

# %%
spark.sql("CREATE DATABASE IF NOT EXISTS iceberg_catalog.default")
# Out:
# DataFrame[]

# %%
spark.sql("""
CREATE TABLE IF NOT EXISTS iceberg_catalog.default.my_table (
    id BIGINT,
    name STRING
) USING iceberg
""")
# Out:
# DataFrame[]

# %%
spark.sql("""
SELECT * FROM iceberg_catalog.default.my_table
""").show()
# Out:
# +---+---------+
# | id|     name|
# +---+---------+
# |  1|KIMJAEMIN|
# |  2|  KIMTEST|
# +---+---------+

# %%
spark.sql("""
INSERT INTO iceberg_catalog.default.my_table
VALUES (1, 'KIMJAEMIN'), (2, 'KIMTEST')
""")
# Out:
# DataFrame[]

# %%
spark.sql("""
UPDATE iceberg_catalog.default.my_table SET name = 'CHOITEST' WHERE id = 2
""")
# Out:
# DataFrame[]

# %%
spark.sql("""
SELECT * FROM iceberg_catalog.default.my_table
""").show()
# Out:
# +---+---------+
# | id|     name|
# +---+---------+
# |  2| CHOITEST|
# |  1|KIMJAEMIN|
# +---+---------+

# %%
spark.sql("""
SELECT * FROM iceberg_catalog.default.my_table.snaphosts
""")
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 spark.sql("""
#       2 SELECT * FROM iceberg_catalog.default.my_table.snaphosts
#       3 """)
#
# File /opt/spark/python/pyspark/sql/session.py:1631, in SparkSession.sql(self, sqlQuery, args, **kwargs)
#    1627         assert self._jvm is not None
#    1628         litArgs = self._jvm.PythonUtils.toArray(
#    1629             [_to_java_column(lit(v)) for v in (args or [])]
#    1630         )
# -> 1631     return DataFrame(self._jsparkSession.sql(sqlQuery, litArgs), self)
#    1632 finally:
#    1633     if len(kwargs) > 0:
#
# File /opt/spark/python/lib/py4j-0.10.9.7-src.zip/py4j/java_gateway.py:1322, in JavaMember.__call__(self, *args)
#    1316 command = proto.CALL_COMMAND_NAME +\
#    1317     self.command_header +\
#    1318     args_command +\
#    1319     proto.END_COMMAND_PART
#    1321 answer = self.gateway_client.send_command(command)
# -> 1322 return_value = get_return_value(
#    1323     answer, self.gateway_client, self.target_id, self.name)
#    1325 for temp_arg in temp_args:
#    1326     if hasattr(temp_arg, "_detach"):
#
# File /opt/spark/python/pyspark/errors/exceptions/captured.py:185, in capture_sql_exception.<locals>.deco(*a, **kw)
#     181 converted = convert_exception(e.java_exception)
#     182 if not isinstance(converted, UnknownException):
#     183     # Hide where the exception came from that shows a non-Pythonic
#     184     # JVM exception message.
# --> 185     raise converted from None
#     186 else:
#     187     raise
#
# AnalysisException: [TABLE_OR_VIEW_NOT_FOUND] The table or view `iceberg_catalog`.`default`.`my_table`.`snaphosts` cannot be found. Verify the spelling and correctness of the schema and catalog.
# If you did not qualify the name with a schema, verify the current_schema() output, or qualify the name with the correct schema and catalog.
# To tolerate the error on drop use DROP VIEW IF EXISTS or DROP TABLE IF EXISTS.; line 2 pos 14;
# 'Project [*]
# +- 'UnresolvedRelation [iceberg_catalog, default, my_table, snaphosts], [], false
